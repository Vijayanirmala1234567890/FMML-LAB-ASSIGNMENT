# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijayanirmala1234567890/FMML-LAB-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 06:15:21--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  79.9MB/s    in 0.9s
#
# 2024-03-25 06:15:22 (79.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29173  1708.06297v1  To efficiently establish training databases fo...    cs
# 155    1606.02396v1  Learning robust value functions given raw obse...  stat
# 38436  1712.08647v1  The Internet facilitates large-scale collabora...    cs
# 299    1708.02977v1  We address the problem of end-to-end visual st...    cs
# 21992   1310.1562v4  We proposed a new statistical dependency measu...  stat
# ...             ...                                                ...   ...
# 12459  1802.03725v1  Networks observed in the real world like socia...    cs
# 32388  1503.06745v1  In this paper, we propose the problem of onlin...    cs
# 18290   0805.1096v1  Affinity propagation clustering (AP) has two l...    cs
# 33597   1404.3023v2  This paper analyses a $(1,\lambda)$-Evolution ...    cs
# 16123  1609.09019v1  Natural language processing techniques are inc...    cs
#
#                                                    title  year  \
# 29173  Employing Weak Annotations for Medical Image A...  2017
# 155                Deep Successor Reinforcement Learning  2016
# 38436  Emo, Love, and God: Making Sense of Urban Dict...  2017
# 299    Hierarchically-Attentive RNN for Album Summari...  2017
# 21992          Dependence Measure for non-additive model  2013
# ...                                                  ...   ...
# 12459   Evolving Latent Space Model for Dynamic Networks  2018
# 32388  Online classifier adaptation for cost-sensitiv...  2015
# 18290           Adaptive Affinity Propagation Clustering  2008
# 33597  Markov Chain Analysis of Evolution Strategies ...  2014
# 16123              Psychologically Motivated Text Mining  2016
#
#                                                 keywords
# 29173  [efficiently, establish, databases, collaborat...
# 155    [functions, observations, reinforcement, algor...
# 38436  [facilitates, collaborative, emergence, platfo...
# 299    [storytelling, representative, storytelling, h...
# 21992  [statistical, dependency, dependency, variable...
# ...                                                  ...
# 12459  [collaboration, disappear, generative, statist...
# 32388  [sensitive, adaptation, algorithm, classifier,...
# 18290  [propagation, clustering, limitations, paramet...
# 33597  [evolution, randomised, comparison, algorithm,...
# 16123  [processing, techniques, increasingly, collect...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29173    [efficiently, establish, databases, collaborat...
# 155      [functions, observations, reinforcement, algor...
# 38436    [facilitates, collaborative, emergence, platfo...
# 299      [storytelling, representative, storytelling, h...
# 21992    [statistical, dependency, dependency, variable...
#                                ...
# 17411    [crosstalk, xiangsheng, traditional, performin...
# 22720    [promising, parameters, differential, equation...
# 6320     [contextual, parameters, simultaneously, gener...
# 25038    [assistance, conditions, dangerous, accidents,...
# 7181     [frequentist, convergence, dirichlet, allocati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8703 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b44306df-fbb2-46ac-b7a1-b9910072ce7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b44306df-fbb2-46ac-b7a1-b9910072ce7f")) {                    Plotly.newPlot(                        "b44306df-fbb2-46ac-b7a1-b9910072ce7f",                        [{"x":["segmentations","employing","associated","annotation","segmentation","abdominal","databases","collaborative","experiments","tomography","approaches","demonstrate","controlled","collectively","realistically","similarly","crowdsourcing","potentially","establish","annotations","different","available","platforms","correction","expertise","investigated","efficiently","environments","functions","predictor","generalizes","including","decomposes","appealing","factorization","components","properties","observations","reinforcement","representations","represents","successor","alternative","algorithms","framework","increased","sensitivity","bottleneck","occupancy","successful","computational","systematic","heterogeneity","drastically","wikipedia","offensive","innovation","information","traditional","qualitative","languages","challenges","environment","dictionaries","susceptible","dictionary","furthermore","opportunities","highlights","processing","decentralized","monitored","unfamiliar","consumers","producers","facilitates","emergence","malfunction","summarization","hierarchically","performance","automatic","baselines","attentive","storytelling","selection","recurrent","generation","evaluations","representative","retrieval","variables","applications","important","statistical","dependence","experimental","appropriate","dependency","implement","dimensional","especially","interested","identification","sufficient","algorithm","distributions","instances","situations","necessary","distribution","exploration","polynomial","superlinear","procedures","identifying","parameter","mathematically","complexity","motivated","constants","assumption","undirected","structures","parameters","regularized","intractable","structure","typically","currently","necessitate","particular","favorably","difficult","synthetic","introduce","generally","reasonable","estimator","optimization","benchmark","efficient","inference","regularization","negligible","calculation","normalizing","identifies","restricted","structural","marginalization","optimized","graphical","consistency","likelihood","validation","criterion","considered","comparison","traditionally","resulting","identical","fundamental","approximation","extensive","dominating","statistics","intervention","considers","considering","robustness","experiment","objective","outperform","definitions","contextual","existence","dramatically","relationships","represent","knowledge","analogical","unsupervised","designers","contribution","stylistic","probabilistic","understood","reasoning","construct","digitally","algebraic","topological","interesting","covariant","homomorphisms","continuous","adjacency","investigate","specifically"],"y":[11,27,107,72,204,2,57,36,632,17,425,599,29,7,5,19,14,40,52,60,754,320,29,21,10,46,182,73,214,10,33,233,7,15,34,98,216,78,129,236,59,6,98,618,577,43,45,14,4,81,299,34,9,11,16,6,8,710,157,50,95,112,118,21,6,56,183,15,8,312,9,5,2,3,3,15,14,2,29,10,852,196,55,8,4,165,146,156,49,42,88,131,450,362,161,29,402,62,46,74,189,113,24,99,72,804,114,103,52,73,238,54,68,1,45,70,120,10,238,59,4,71,12,123,245,37,25,332,110,56,1,287,13,140,146,341,56,32,29,338,202,414,235,89,10,15,2,16,36,76,3,63,60,70,73,59,39,143,133,28,165,12,91,133,174,2,72,15,36,62,100,81,178,103,24,55,36,17,81,103,362,3,152,7,65,4,155,22,134,98,2,23,20,79,3,3,97,7,137,178],"type":"bar"},{"x":["segmentations","employing","associated","annotation","segmentation","abdominal","databa ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>EXMOVES</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifier</span> <span style=''>based</span> <span style=''>Features</span> <span style=''>for</span> <span style=''>Scalable</span> <span style=''>Action</span> <span style='background-color:rgba(0, 255, 0, 0.6440677966101696);'>Recognition</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>EXMOVES</span> <span style=''>learned</span> <span style=''>exemplar</span> <span style=''>based</span> <span style=''>features</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.6440677966101696);'>recognition</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>in</span> <span style=''>videos</span> <span style=''>The</span> <span style=''>entries</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>descriptor</span> <span style=''>are</span> <span style=''>produced</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.5053763440860215);'>evaluating</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>movement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>over</span> <span style=''>spatial</span> <span style=''>temporal</span> <span style=''>volumes</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>sequence</span> <span style=''>Each</span> <span style=''>movement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>exemplar</span> <span style=''>SVM</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>low</span> <span style=''>level</span> <span style=''>features</span> <span style=''>ie</span> <span style=''>an</span> <span style=''>SVM</span> <span style=''>learned</span> <span style=''>using</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.8125);'>annotated</span> <span style=''>positive</span> <span style=''>space</span> <span style=''>time</span> <span style=''>volume</span> <span style=''>and</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unannotated</span> <span style=''>videos</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3757009345794393);'>representation</span> <span style=''>offers</span> <span style=''>two</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>First</span> <span style=''>since</span> <span style=''>our</span> <span style=''>mid</span> <span style=''>level</span> <span style=''>features</span> <span style=''>are</span> <span style=''>learned</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>video</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>exemplars</span> <span style=''>they</span> <span style=''>require</span> <span style=''>minimal</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6619718309859155);'>supervision</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>simple</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>models</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>our</span> <span style=''>global</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Bound</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style=''>Transfer</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>transfer</span> <span style=''>approach</span> <span style=''>where</span> <span style=''>a</span> <span style=''>suitable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>mapping</span> <span style=''>is</span> <span style=''>learned</span> <span style=''>through</span> <span style=''>one</span> <span style=''>task</span> <span style=''>and</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>another</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>task</span> <span style=''>Then</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>transfer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>feature</span> <span style=''>mappingand</span> <span style=''>thereby</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>bound</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>transfer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>As</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>in</span> <span style=''>self</span> <span style=''>taught</span> <span style=''>learning</span> <span style=''>Although</span> <span style=''>self</span> <span style=''>taught</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>plentiful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>often</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excellent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Combinatorial</span> <span style=''>Topic</span> <span style=''>Models</span> <span style=''>using</span> <span style=''>Small</span> <span style=''>Variance</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Asymptotics</span> <br/><br/><span style=''>Topic</span> <span style=''>models</span> <span style=''>have</span> <span style=''>emerged</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>tools</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Most</span> <span style=''>modern</span> <span style=''>topic</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>take</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>view</span> <span style=''>and</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Latent</span> <span style='background-color:rgba(255, 0, 0, 0.39473684210526305);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>(LDA)</span> <span style=''>or</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>we</span> <span style=''>study</span> <span style=''>topic</span> <span style=''>modeling</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>LDA</span> <span style=''>by</span> <span style=''>passing</span> <span style=''>to</span> <span style=''>the</span> <span style=''>small</span> <span style=''>variance</span> <span style=''>limit</span> <span style=''>We</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>derived</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>by</span> <span style=''>using</span> <span style=''>ideas</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>which</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>new</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>topic</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>results</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>popular</span> <span style=''>LDA</span> <span style=''>based</span> <span style=''>topic</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>and</span> <span style=''>also</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>(dis)similarities</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Avoiding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrimination</span> <span style=''>through</span> <span style=''>Causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reasoning</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>fairness</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>criteria</span> <span style=''>and</span> <span style=''>how</span> <span style=''>they</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>Most</span> <span style=''>of</span> <span style=''>these</span> <span style=''>criteria</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>They</span> <span style=''>depend</span> <span style=''>only</span> <span style=''>on</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>protected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attribute</span> <span style=''>features</span> <span style=''>and</span> <span style=''>outcome</span> <span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convenient</span> <span style=''>to</span> <span style=''>work</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>criteria</span> <span style=''>have</span> <span style=''>severe</span> <span style=''>inherent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>that</span> <span style=''>prevent</span> <span style=''>them</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolving</span> <span style=''>matters</span> <span style=''>of</span> <span style=''>fairness</span> <span style=''>conclusively</span> <span style=''>Going</span> <span style=''>beyond</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>criteria</span> <span style=''>we</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>protected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>language</span> <span style=''>of</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>shifts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>from</span> <span style=''>What</span> <span style=''>is</span> <span style=''>the</span> <span style=''>right</span> <span style=''>fairness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style=''>What</span> <span style=''>do</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style=''>assume</span> <span style=''>about</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>process</span> <span style=''>Through</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13208901651112706)
# 	segmentation (0.0732232591529074)
# 	knowledge (0.1299353912419239)
# 	processing (0.11198851399856424)
# 	experimental (0.14429289303661164)
# 	information (0.2548456568557071)
# 	detection (0.12778176597272076)
# 	different (0.2706389088298636)
# 	convolutional (0.1302943287867911)
# 	recognition (0.13926776740847094)
#
# Some Statistics words are:
# 	theoretical (0.14150943396226415)
# 	variables (0.13704071499503476)
# 	estimation (0.16683217477656406)
# 	statistical (0.15441906653426019)
# 	algorithm (0.3887785501489573)
# 	stochastic (0.14349553128103276)
# 	distribution (0.18768619662363456)
# 	inference (0.19860973187686196)
# 	regression (0.16981132075471697)
# 	dimensional (0.19910625620655412)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="401aab0b-8ae0-415d-a80b-cd8c791c6e0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("401aab0b-8ae0-415d-a80b-cd8c791c6e0f")) {                    Plotly.newPlot(                        "401aab0b-8ae0-415d-a80b-cd8c791c6e0f",                        [{"x":["segmentations","employing","associated","annotation","segmentation","abdominal","databases","collaborative","experiments","tomography","approaches","demonstrate","controlled","collectively","realistically","similarly","crowdsourcing","potentially","establish","annotations","different","available","platforms","correction","expertise","investigated","efficiently","environments","functions","predictor","generalizes","including","decomposes","appealing","factorization","components","properties","observations","reinforcement","representations","represents","successor","alternative","algorithms","framework","increased","sensitivity","bottleneck","occupancy","successful","computational","systematic","heterogeneity","drastically","wikipedia","offensive","innovation","information","traditional","qualitative","languages","challenges","environment","dictionaries","susceptible","dictionary","furthermore","opportunities","highlights","processing","decentralized","monitored","unfamiliar","consumers","producers","facilitates","emergence","malfunction","summarization","hierarchically","performance","automatic","baselines","attentive","storytelling","selection","recurrent","generation","evaluations","representative","retrieval","variables","applications","important","statistical","dependence","experimental","appropriate","dependency","implement","dimensional","especially","interested","identification","sufficient","algorithm","distributions","instances","situations","necessary","distribution","exploration","polynomial","superlinear","procedures","identifying","parameter","mathematically","complexity","motivated","constants","assumption","undirected","structures","parameters","regularized","intractable","structure","typically","currently","necessitate","particular","favorably","difficult","synthetic","introduce","generally","reasonable","estimator","optimization","benchmark","efficient","inference","regularization","negligible","calculation","normalizing","identifies","restricted","structural","marginalization","optimized","graphical","consistency","likelihood","validation","criterion","considered","comparison","traditionally","resulting","identical","fundamental","approximation","extensive","dominating","statistics","intervention","considers","considering","robustness","experiment","objective","outperform","definitions","contextual","existence","dramatically","relationships","represent","knowledge","analogical","unsupervised","designers","contribution","stylistic","probabilistic","understood","reasoning","construct","digitally","algebraic","topological","interesting","covariant","homomorphisms","continuous","adjacency","investigate","specifically","relations","dimension","uncorrelated","conditions","coefficients","regardless","measurements","regression","completely","assumptions","characterize","correlated","independent","generating","estimation","accurately","clustering","generative","hindsight","implications","constraints","minimization","ambitious","projection","approached","arbitrary","extension","expansion","approachability","switching","approachable","impossible","performed","achievable","repeatedly","frequently","subgroups","biomedical","particularly","homogeneous","correctly","biologically","scenarios","conventional","microarray","simulation","secondary","prospective","disorders","modification","definition","potential","generated","application","disparities","algorithmic","ac ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	approachability
# 	prospective
# 	integrand
# 	consonants
# 	montanari
# 	prescribe
# 	prescriptive
# 	unnormalized
# 	individualized
# 	prognostic
# 	epidemiology
# 	operationalize
# 	coalescent
# 	combustion
# 	prognostics
# 	transplantation
# 	delineates
# 	revolutionize
# 	semiparametric
# 	oscillates
# Some words which never appear in Statistics papers:
# 	realistically
# 	consumers
# 	malfunction
# 	storytelling
# 	dominating
# 	analogical
# 	stylistic
# 	covariant
# 	homomorphisms
# 	imprecision
# 	exchanged
# 	curiosity
# 	negotiation
# 	stereoscopic
# 	luminance
# 	compilation
# 	experimented
# 	interfering
# 	erroneously
# 	pathologist

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.08413520848754e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
